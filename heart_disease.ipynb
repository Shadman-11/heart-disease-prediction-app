# %%
import numpy as np

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Heart_Disease_Prediction (1).csv')

# %%
df.shape
# Out:
# (270, 14)

# %%
df.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
df['Heart Disease'].value_counts()
# Out:
# Heart Disease
# Absence     150
# Presence    120
# Name: count, dtype: int64

# %%
df['Heart Disease']=df['Heart Disease'].map({"Presence":1,"Absence":0})

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        3         3              1
# 1                        0         7              0
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease                int64
# dtype: object

# %%
df['Heart Disease'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Heart Disease'>

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120',
#        'EKG results', 'Max HR', 'Exercise angina', 'ST depression',
#        'Slope of ST', 'Number of vessels fluro', 'Thallium', 'Heart Disease'],
#       dtype='object')

# %%
sns.countplot(x=df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        3         3              1
# 1                        0         7              0
# ...

# %%
sns.countplot(x=df['Chest pain type'],hue=df['Heart Disease'])
# Out:
# <Axes: xlabel='Chest pain type', ylabel='count'>

# %%
sns.countplot(x=df['Cholesterol'],hue=df['Heart Disease'])
# Out:
# <Axes: xlabel='Cholesterol', ylabel='count'>

# %%
sns.countplot(x=df['FBS over 120'],hue=df['Heart Disease'])
# Out:
# <Axes: xlabel='FBS over 120', ylabel='count'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        3         3              1
# 1                        0         7              0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,f1_score,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
df_enc=df.copy()
df_enc.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        3         3              1
# 1                        0         7              0
# ...

# %%
X=df_enc.drop('Heart Disease',axis=1)
y=df_enc['Heart Disease']

# %%
X_train, X_test, y_train, y_test = train_test_split(
 X, y, test_size=0.33, random_state=42)

# %%
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
model={
    "Logistic Regression":LogisticRegression(),
    "KNN":KNeighborsClassifier(),
    "Native Byes":GaussianNB(),
    "Decision Tree":DecisionTreeClassifier(),
    "SVM":SVC()
}

# %%
result=[]

# %%
for name,model in model.items():
  model.fit(X_train_scaled,y_train)
  y_pred=model.predict(X_test_scaled)
  acc=accuracy_score(y_test,y_pred)
  f1=f1_score(y_test,y_pred)
  result.append({
      'model':name,
      'accuracy':round(acc,4),
      'f1_score':round(f1,4)
  })

# %%
result
# Out:
# [{'model': 'Logistic Regression', 'accuracy': 0.7889, 'f1_score': 0.7246},
#  {'model': 'KNN', 'accuracy': 0.8111, 'f1_score': 0.7463},
#  {'model': 'Native Byes', 'accuracy': 0.8556, 'f1_score': 0.806},
#  {'model': 'Decision Tree', 'accuracy': 0.7222, 'f1_score': 0.6575},
#  {'model': 'SVM', 'accuracy': 0.8111, 'f1_score': 0.7606}]

# %%
from sklearn.naive_bayes import GaussianNB
import joblib

nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

joblib.dump(nb_model, 'Naive_Bayes_heart.pkl')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(X.columns.tolist(), 'columns.pkl')
# Out:
# ['columns.pkl']

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'columns.pkl', 'Naive_Bayes_heart.pkl', 'scaler.pkl', 'Heart_Disease_Prediction (1).csv', 'sample_data']

# %%
from google.colab import files

files.download('Naive_Bayes_heart.pkl')
files.download('scaler.pkl')
files.download('columns.pkl')
